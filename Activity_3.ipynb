# %% [markdown]
# <a href="https://colab.research.google.com/github/AtLobster/ML-course/blob/main/Activity_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My Colab Practice Notebook

# %% [markdown]
# Group 7: Atte Sten, Tomi Vartiainen, Fahim Billah, Yavuz Yilmaz

# %%
print("Hello, world! Activity 3 is starting.")
# Out:
# Hello, world! Activity 3 is starting.

# %% [markdown]
# # Activity 3: Markdown Mastery
#
# ## Why Markdown?
# Markdown is a **simple** way to format text. It allows us to:
# * Organize code with *headings*
# * Highlight `specific_variables` using backticks
# * Create clean lists for documentation
#
# ### My Group's Goals
# 1. Learn Python basics
# 2. Understand Machine Learning
# 3. Build a final project

# %% [markdown]
# ### Useful Colab Features
#
# | Feature | Shortcut/Usage |
# |---|---|
# | **Code Cell** | `Cmd/Ctrl + B + M` |
# | **Run Cell** | `Shift + Enter` |
# | **Table of Contents** | Left Sidebar icon |

# %%
print("Python can be used in Colab too :-)")
# Out:
# Markdown and Python can be used in the same Colab notebook.
